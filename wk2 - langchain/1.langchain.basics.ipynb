# %%
# %run ../shared_notebook_setup.py

# %% [markdown]
# ### 2. Developing using Langchain API

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model=DATABRICKS_MODEL,
    api_key=DATABRICKS_TOKEN,
    base_url=f"{DATABRICKS_HOST}/serving-endpoints",
)

msg = llm.invoke("What is Python in one sentence?")
# Out:
# [{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'Thinking Process:\n\n1.  **Analyze the Request:**\n    *   Question: "What is Python in one sentence?"\n    *   Constraint: The answer must be exactly one sentence.\n    *   Subject: Python (programming language).\n    *   Goal: Provide a concise, accurate, and informative definition.\n\n2.  **Identify Key Characteristics of Python:**\n    *   Programming language.\n    *   High-level.\n    *   Interpreted.\n    *   General-purpose.\n    *   Emphasizes code readability (indents, clean syntax).\n    *   Popular in web development, data science, AI/ML, scripting, etc.\n\n3.  **Draft Initial Ideas:**\n    *   Python is a programming language that is easy to read and uses indentation.\n    *   Python is a high-level, interpreted programming language known for its simple syntax and versatility.\n    *   Created by Guido van Rossum, Python is used for web development, data science, and automation.\n    *   Python is a popular programming language that allows developers to write clear code efficiently.\n\n4.  **Refine for Accuracy and Completeness (within one sentence):**\n    *   *Draft:* Python is a high-level, interpreted programming language known for its readability and versatility in fields like web development, data science, and automation.\n    *   *Critique:* Accurate, covers key aspects (high-level, interpreted, readability, versatility). Length is fine.\n\n5.  **Check Constraints:**\n    *   Is it one sentence? Yes.\n    *   Does it answer "What is Python"? Yes.\n\n6.  **Final Polish:**\n    *   "Python is a high-level, interpreted programming language known for its clear syntax and versatility in fields like web development, data science, and artificial intelligence."\n    *   *Simpler version:* "Python is a high-level, general-purpose programming language known for its readability and versatility across various applications."\n\n    Let\'s go with a version that balances technical classification with its main selling point (readability/ease of use).\n\n    *Selected:* Python is a high-level, interpreted programming language renowned for its clear syntax and versatility in applications ranging from web development to artificial intelligence.\n\n7.  **Final Count Check:** One sentence ending with a period.\n\n    *Alternative (more concise):* Python is a versatile, high-level programming language known for its simple syntax and readability.\n\n    Let\'s choose the one that gives a bit more context (fields of use) while remaining one sentence.\n\n    *Revised:* Python is a high-level, interpreted programming language known for its readability and versatility in areas such as web development, data science, and automation.\n\n    *Even tighter:* Python is a popular, high-level programming language known for its simple syntax and wide range of applications in fields like software development and data science.\n\n    Let\'s stick to the core definition.\n\n    *Final Choice:* Python is a high-level, interpreted programming language known for its clear syntax and versatility in fields ranging from web development to artificial intelligence.\n\n    Wait, I can make it slightly more definitive.\n    "Python is a high-level, general-purpose programming language that emphasizes code readability and is widely used in fields such as web development, data science, and automation."\n\n    That works.\n\n8.  **Output Generation** (matching the thought process to the final output).\n    "Python is a high-level, general-purpose programming language known for its clear syntax and versatility in fields ranging from web development to artificial intelligence."\n\n    Actually, let\'s keep it punchy.\n    "Python is a high-level, interpreted programming language renowned for its readability and versatility across applications like web development, data science, and automation."\n\n    Okay, I will output that.cw'}]}, {'type': 'text', 'text': 'Python is a high-level, interpre ...

# %%
print(msg.content)
print(json.dumps(msg.content, indent=2))
# Out:
# [{'type': 'reasoning', 'summary': [{'type': 'summary_text', 'text': 'Thinking Process:\n\n1.  **Analyze the Request:**\n    *   Question: "What is Python in one sentence?"\n    *   Constraint: The answer must be exactly one sentence.\n    *   Subject: Python (programming language).\n    *   Goal: Provide a concise, accurate, and informative definition.\n\n2.  **Identify Key Characteristics of Python:**\n    *   Programming language.\n    *   High-level.\n    *   Interpreted.\n    *   General-purpose.\n    *   Emphasizes code readability (indents, clean syntax).\n    *   Popular in web development, data science, AI/ML, scripting, etc.\n\n3.  **Draft Initial Ideas:**\n    *   Python is a programming language that is easy to read and uses indentation.\n    *   Python is a high-level, interpreted programming language known for its simple syntax and versatility.\n    *   Created by Guido van Rossum, Python is used for web development, data science, and automation.\n    *   Python is a popular programming language that allows developers to write clear code efficiently.\n\n4.  **Refine for Accuracy and Completeness (within one sentence):**\n    *   *Draft:* Python is a high-level, interpreted programming language known for its readability and versatility in fields like web development, data science, and automation.\n    *   *Critique:* Accurate, covers key aspects (high-level, interpreted, readability, versatility). Length is fine.\n\n5.  **Check Constraints:**\n    *   Is it one sentence? Yes.\n    *   Does it answer "What is Python"? Yes.\n\n6.  **Final Polish:**\n    *   "Python is a high-level, interpreted programming language known for its clear syntax and versatility in fields like web development, data science, and artificial intelligence."\n    *   *Simpler version:* "Python is a high-level, general-purpose programming language known for its readability and versatility across various applications."\n\n    Let\'s go with a version that balances technical classification with its main selling point (readability/ease of use).\n\n    *Selected:* Python is a high-level, interpreted programming language renowned for its clear syntax and versatility in applications ranging from web development to artificial intelligence.\n\n7.  **Final Count Check:** One sentence ending with a period.\n\n    *Alternative (more concise):* Python is a versatile, high-level programming language known for its simple syntax and readability.\n\n    Let\'s choose the one that gives a bit more context (fields of use) while remaining one sentence.\n\n    *Revised:* Python is a high-level, interpreted programming language known for its readability and versatility in areas such as web development, data science, and automation.\n\n    *Even tighter:* Python is a popular, high-level programming language known for its simple syntax and wide range of applications in fields like software development and data science.\n\n    Let\'s stick to the core definition.\n\n    *Final Choice:* Python is a high-level, interpreted programming language known for its clear syntax and versatility in fields ranging from web development to artificial intelligence.\n\n    Wait, I can make it slightly more definitive.\n    "Python is a high-level, general-purpose programming language that emphasizes code readability and is widely used in fields such as web development, data science, and automation."\n\n    That works.\n\n8.  **Output Generation** (matching the thought process to the final output).\n    "Python is a high-level, general-purpose programming language known for its clear syntax and versatility in fields ranging from web development to artificial intelligence."\n\n    Actually, let\'s keep it punchy.\n    "Python is a high-level, interpreted programming language renowned for its readability and versatility across applications like web development, data science, and automation."\n\n    Okay, I will output that.cw'}]}, {'type': 'text', 'text': 'Python is a high-level, interpre ...
# [
#   {
#     "type": "reasoning",
#     "summary": [
#       {
#         "type": "summary_text",
#         "text": "Thinking Process:\n\n1.  **Analyze the Request:**\n    *   Question: \"What is Python in one sentence?\"\n    *   Constraint: The answer must be exactly one sentence.\n    *   Subject: Python (programming language).\n    *   Goal: Provide a concise, accurate, and informative definition.\n\n2.  **Identify Key Characteristics of Python:**\n    *   Programming language.\n    *   High-level.\n    *   Interpreted.\n    *   General-purpose.\n    *   Emphasizes code readability (indents, clean syntax).\n    *   Popular in web development, data science, AI/ML, scripting, etc.\n\n3.  **Draft Initial Ideas:**\n    *   Python is a programming language that is easy to read and uses indentation.\n    *   Python is a high-level, interpreted programming language known for its simple syntax and versatility.\n    *   Created by Guido van Rossum, Python is used for web development, data science, and automation.\n    *   Python is a popular programming language that allows developers to write clear code efficiently.\n\n4.  **Refine for Accuracy and Completeness (within one sentence):**\n    *   *Draft:* Python is a high-level, interpreted programming language known for its readability and versatility in fields like web development, data science, and automation.\n    *   *Critique:* Accurate, covers key aspects (high-level, interpreted, readability, versatility). Length is fine.\n\n5.  **Check Constraints:**\n    *   Is it one sentence? Yes.\n    *   Does it answer \"What is Python\"? Yes.\n\n6.  **Final Polish:**\n    *   \"Python is a high-level, interpreted programming language known for its clear syntax and versatility in fields like web development, data science, and artificial intelligence.\"\n    *   *Simpler version:* \"Python is a high-level, general-purpose programming language known for its readability and versatility across various applications.\"\n\n    Let's go with a version that balances technical classification with its main selling point (readability/ease of use).\n\n    *Selected:* Python is a high-level, interpreted programming language renowned for its clear syntax and versatility in applications ranging from web development to artificial intelligence.\n\n7.  **Final Count Check:** One sentence ending with a period.\n\n    *Alternative (more concise):* Python is a versatile, high-level programming language known for its simple syntax and readability.\n\n    Let's choose the one that gives a bit more context (fields of use) while remaining one sentence.\n\n    *Revised:* Python is a high-level, interpreted programming language known for its readability and versatility in areas such as web development, data science, and automation.\n\n    *Even tighter:* Python is a popular, high-level programming language known for its simple syntax and wide range of applications in fields like software development and data science.\n\n    Let's stick to the core definition.\n\n    *Final Choice:* Python is a high-level, interpreted programming language known for its clear syntax and versatility in fields ranging from web development to artificial intelligence.\n\n    Wait, I can make it slightly more definitive.\n    \"Python is a high-level, general-purpose programming language that emphasizes code readability and is widely used in fields such as web development, data science, and automation.\"\n\n    That works.\n\n8.  **Output Generation** (matching the thought process to the final output).\n    \"Python is a high-level, general-purpose programming language known for its clear syntax and versatility in fields ranging from web development to artificial intelligence.\"\n\n    Actually, let's keep it punchy.\n    \"Python is a high-level, interpreted programming language renowned for its readability and versatility across applications like web development, data science, and automation.\"\n\n    Okay, I will output that.cw"
#       }
#     ]
#   },
#   {
#     "type": "text",
#     "text": "Python is a high-level, interpreted programming language renowned for its clear syntax and versatility across applications ranging from web development to artificial intelligence."
#   }
# ]

# %% [markdown]
# ### 3. Creating Basic Chain using Langchain Expression Language (LCEL)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in 3 short bullet points."
)

chain = prompt | llm | StrOutputParser()

result = chain.invoke({"topic": "LangChain"})
print(result)
# Out:
# *   **Framework:** An open-source library designed to simplify building applications powered by large language models (LLMs).
# *   **Orchestration:** Enables developers to chain prompts, manage context, and coordinate complex AI workflows.
# *   **Integration:** Provides pre-built connectors for easily linking LLMs to external data sources, APIs, and tools.

# %%
# Reusing existing template and chain with different topics
for t in ["LangChain", "Prompt Engineering", "Vector Databases"]:
    print(chain.invoke({"topic": t}))
    print("-" * 60)
# Out:
# *   **Framework for LLMs:** It is an open-source toolkit designed to simplify building applications powered by large language models.
# *   **Modular Integration:** It provides components to easily connect LLMs with external data sources, APIs, and memory.
# *   **Workflow Orchestration:** It enables developers to chain prompts, models, and logic together to create complex AI workflows.
# ------------------------------------------------------------
# *   It is the practice of crafting precise text inputs to guide AI models toward specific, high-quality outputs.
# *   Effective prompts use clear instructions, context, and examples to minimize ambiguity and improve the model's understanding.
# *   The goal is to optimize AI performance, ensuring responses are accurate, relevant, and efficient for the task.
# ------------------------------------------------------------
# *   **Storage:** They store unstructured data as high-dimensional vector embeddings that capture semantic meaning and context.
# *   **Search:** They enable ultra-fast similarity searches to find mathematically "closest" matches rather than relying on exact keyword matches.
# *   **Application:** They power key AI workflows like semantic search, recommendation systems, and Retrieval-Augmented Generation (RAG) for LLMs.
# ------------------------------------------------------------
